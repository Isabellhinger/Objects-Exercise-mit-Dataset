# %% [markdown]
# # Objects
# ## When not to use Objects
# Objects are best used, when you group methods and data together. If you just want to group data together use e.g. a dictionary.

# %%
import csv
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# %% [markdown]
# ## Dictionary
# Dictionaries can store multiple values like lists. In difference to lists, the values are not accessed by their position, but by name. Dictionaries can be compared to a telephone book, to the index of a book or to an inventory. For every item there are two variables, the key and the value. The key is in the telephone book example the name of the user, the value is the telephone number.
#
# If we read in the data from last time into a dictionary, we can do this as follows:

# %%
data = {}
with open('de-nrw-dortmund-versorgung_mit_energie_und_wasser_seit_1994.csv', 'r', encoding='latin1') as csvfile:
    rows = csv.reader(csvfile, delimiter=';', quotechar='"')
    #read in the header line
    headers = next(rows, None)
    #generate a list of values for every heading
    for header in headers:
        data[header]=[]
    for row in rows:
        #for every entry in headers and row (first header in h, first row-entry in v and so on)
        for h,v in zip(headers, row):
            #if v is a number, convert the value
            if (v.isdigit):
                data[h].append(int(v))
            elif (v.isdecimal):
                data[h].append(float(v))
            else:  
                data[h].append(v)
print(data)
# Out:
# {'Jahr': [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], 'Erdgasverkauf insgesamt in Mill kWh': [4804, 5052, 5636, 4943, 4942, 4639, 4478, 4803, 4869, 5109, 5152, 4882, 4766, 4490, 4746, 4462, 4980, 4485, 4672, 4855, 4022, 4484, 4808, 4838], 'darunter Erdgasverkauf an Privatkunden': [3464, 3701, 4268, 3727, 3760, 3482, 3393, 3606, 3466, 3569, 3625, 3368, 3303, 3027, 3243, 2995, 3181, 2477, 2757, 2693, 1987, 2163, 2147, 1989], 'darunter Erdgasverkauf an Geschäftskunden': [1340, 1350, 1369, 1216, 1182, 1158, 1085, 1197, 1199, 1339, 1287, 1271, 1235, 1218, 1215, 1007, 980, 1009, 901, 896, 961, 1009, 547, 573], 'Stromverkauf insgesamt in Mill kWh': [2207, 2196, 2236, 2204, 2223, 2218, 2234, 2255, 2291, 2336, 2386, 2396, 2411, 2385, 2422, 2380, 2361, 2369, 2357, 2309, 2258, 2263, 2189, 2157], 'darunter Stromverkauf an Privatkunden': [1064, 1067, 1110, 1075, 1070, 1040, 1026, 1032, 1012, 1066, 1024, 1016, 1008, 956, 957, 884, 914, 849, 893, 872, 870, 856, 795, 755], 'darunter Stromverkauf an Geschäftskunden': [1142, 1129, 1126, 1129, 1153, 1178, 1143, 1089, 1080, 1053, 1130, 1198, 1199, 1176, 1118, 975, 763, 807, 712, 667, 627, 616, 553, 571], 'Fernwärmeverkauf in Mill kWh': [392, 393, 450, 429, 421, 401, 373, 398, 372, 376, 363, 341, 433, 382, 391, 387, 418, 366, 378, 394, 318, 331, 344, 333], 'Nahwärmeverkauf in Mill kWh': [158, 169, 214, 198, 245, 248, 251, 266, 260, 249, 271, 243, 245, 221, 255, 245, 290, 239, 245, 261, 182, 258, 244, 255], 'Wasserverkauf insgesamt in Mill m³': [60, 59, 59, 59, 56, 52, 52, 47, 42, 41, 40, 38, 37, 36, 36, 35, 35, 36, 35, 35, 34, 34, 36, 35], 'davon an Privatkunden': [39, 38, 37, 37, 36, 36, 36, 37, 36, 35, 34, 32, 32, 31, 32, 31, 31, 31, 31, 31, 30, 30, 32, 31], 'davon an Geschäftskunden': [22, 21, 22, 22, 20, 16, 16, 10, 6, 6, 6, 6, 5, 5, 5, 4, 4, 5, 4, 4, 4, 4, 4, 4]}

# %% [markdown]
# ## Usage of a dictionary
# A dictionary in python can be used at different places in the standard API, and also in 3rd party modules. (More about modules next time)

# %%
# Skip the first column, those are the years.
for y in range(1, len(headers)):
    #only show the first 10 characters in the label
    plt.plot(data["Jahr"],data[headers[y]], label=headers[y][:10])
#show labels together with the corresponding colors
plt.legend()

# %% [markdown]
# ## Usage of builtin Classes
# The lists we worked with last time are an example of classes which are built in to python, as are Strings, Sets, Dictionaries, Tupels, Range, ...
#
# Broadly speaking, in python everything is an object. ```"Hello World"``` is an example of an object of the class ```str``` (String). It has, for example the method ```upper```, which switches all of the characters to upper case. The number ```2``` is an example of an object of the class ```int```, ```[5, 19]``` is an example for an object of the class ```list```.

# %%
text = "Hello World"
print (text.upper())
print (type(text))

number = 2
print (type(number))

tax = [7, 19]
print(tax)
print (type(tax))
tax.clear()
print (tax)
# Out:
# HELLO WORLD
# <class 'str'>
# <class 'int'>
# [7, 19]
# <class 'list'>
# []

# %% [markdown]
# ## Define your own class
# A class can store different values (=> attributes) and methods for each member (=> object) of the class.
#
# In our example it means, that every pokemon has a name that is unique for this kind of pokemon. This means, that pikachu is an object of the class pokemon.
#
# It is also possible to store information on the class itself. In our example this is the pokedex, which is a list of all the pokemons which are known. This is information which is not special for one pokemon (=> object), but is common for all objects of the class pokemon.
#
# All of the values, which are returned by the ```csv.reader``` are of the class ```str```. In this example there is a conversion for the hp attribute to ```int```. Only when we use this, we can calculate with the values in the hp attribute.

# %%
class pokemon:
    pokedex = []
    def __init__(self, name, total, type, hp, attack, defense, generation):
        self.name = name
        self.type= type
        self.total = total
        self.hp=int(hp)
        self.attack=int(attack)
        self.defense=int(defense)
        self.generation=generation
        self.pokedex.append(self)
    def __repr__(self):
        return "Pokemon: " + self.name + " Type: " + self.type + " Generation: " + self.generation
    def color(self):
        switcher = {
            'Fire':'red',
            'Grass':'green',
            'Bug':'green',
            'Ice':'blue',
            'Water':'blue',
            'Normal':'grey',
            'Electric':'yellow',
            'Ground':'brown',
            'Poison':'green',
            'Fairy':'blue',
            'Fighting':'yellow',
            'Dark':'grey',
            'Psychic':'grey',
            'Rock':'grey',
            'Ghost':'white',
            'Dragon':'blue'
        }
        return switcher[self.type]

# %% [markdown]
# ## Build your pokedex
# To read information from a file, you can use the method (```open``` file, skip header and use ```csv.reader```) we saw last time. If you call ```pokemon()``` by convention in python the method ```__init__```is called.

# %%
with open('pokemon.csv', 'r') as csvfile:
    rows = csv.reader(csvfile, delimiter=',', quotechar='"')
    #Skip Header line
    next(rows)
    for row in rows:
        pokemon(name=row[1], type=row[2], total = row[4], hp=row[5], attack=row[6], defense=row[7], generation=row[11])
pokemon.pokedex
# Out:
# [Pokemon: Bulbasaur Type: Grass Generation: 1,
#  Pokemon: Ivysaur Type: Grass Generation: 1,
#  Pokemon: Venusaur Type: Grass Generation: 1,
#  Pokemon: VenusaurMega Venusaur Type: Grass Generation: 1,
#  Pokemon: Charmander Type: Fire Generation: 1,
#  Pokemon: Charmeleon Type: Fire Generation: 1,
#  Pokemon: Charizard Type: Fire Generation: 1,
#  Pokemon: CharizardMega Charizard X Type: Fire Generation: 1,
#  Pokemon: CharizardMega Charizard Y Type: Fire Generation: 1,
#  Pokemon: Squirtle Type: Water Generation: 1,
#  Pokemon: Wartortle Type: Water Generation: 1,
#  Pokemon: Blastoise Type: Water Generation: 1,
#  Pokemon: BlastoiseMega Blastoise Type: Water Generation: 1,
#  Pokemon: Caterpie Type: Bug Generation: 1,
#  Pokemon: Metapod Type: Bug Generation: 1,
#  Pokemon: Butterfree Type: Bug Generation: 1,
#  Pokemon: Weedle Type: Bug Generation: 1,
#  Pokemon: Kakuna Type: Bug Generation: 1,
#  Pokemon: Beedrill Type: Bug Generation: 1,
#  Pokemon: BeedrillMega Beedrill Type: Bug Generation: 1,
#  Pokemon: Pidgey Type: Normal Generation: 1,
#  Pokemon: Pidgeotto Type: Normal Generation: 1,
#  Pokemon: Pidgeot Type: Normal Generation: 1,
#  Pokemon: PidgeotMega Pidgeot Type: Normal Generation: 1,
#  Pokemon: Rattata Type: Normal Generation: 1,
#  Pokemon: Raticate Type: Normal Generation: 1,
#  Pokemon: Spearow Type: Normal Generation: 1,
#  Pokemon: Fearow Type: Normal Generation: 1,
#  Pokemon: Ekans Type: Poison Generation: 1,
#  Pokemon: Arbok Type: Poison Generation: 1,
#  Pokemon: Pikachu Type: Electric Generation: 1,
#  Pokemon: Raichu Type: Electric Generation: 1,
#  Pokemon: Sandshrew Type: Ground Generation: 1,
#  Pokemon: Sandslash Type: Ground Generation: 1,
#  Pokemon: Nidoran♀ Type: Poison Generation: 1,
#  Pokemon: Nidorina Type: Poison Generation: 1,
#  Pokemon: Nidoqueen Type: Poison Generation: 1,
#  Pokemon: Nidoran♂ Type: Poison Generation: 1,
#  Pokemon: Nidorino Type: Poison Generation: 1,
#  Pokemon: Nidoking Type: Poison Generation: 1,
#  Pokemon: Clefairy Type: Fairy Generation: 1,
#  Pokemon: Clefable Type: Fairy Generation: 1,
#  Pokemon: Vulpix Type: Fire Generation: 1,
#  Pokemon: Ninetales Type: Fire Generation: 1,
#  Pokemon: Jigglypuff Type: Normal Generation: 1,
#  Pokemon: Wigglytuff Type: Normal Generation: 1,
#  Pokemon: Zubat Type: Poison Generation: 1,
#  Pokemon: Golbat Type: Poison Generation: 1,
#  Pokemon: Oddish Type: Grass Generation: 1,
#  Pokemon: Gloom Type: Grass Generation: 1,
#  Pokemon: Vileplume Type: Grass Generation: 1,
#  Pokemon: Paras Type: Bug Generation: 1,
#  Pokemon: Parasect Type: Bug Generation: 1,
#  Pokemon: Venonat Type: Bug Generation: 1,
#  Pokemon: Venomoth Type: Bug Generation: 1,
#  Pokemon: Diglett Type: Ground Generation: 1,
#  Pokemon: Dugtrio Type: Ground Generation: 1,
#  Pokemon: Meowth Type: Normal Generation: 1,
#  Pokemon: Persian Type: Normal Generation: 1,
#  Pokemon: Psyduck Type: Water Generation: 1,
#  Pokemon: Golduck Type: Water Generation: 1,
#  Pokemon: Mankey Type: Fighting Generation: 1,
#  Pokemon: Primeape Type: Fighting Generation: 1,
#  Pokemon: Growlithe Type: Fire Generation: 1,
#  Pokemon: Arcanine Type: Fire Generation: 1,
#  Pokemon: Poliwag Type: Water Generation: 1,
#  Pokemon: Poliwhirl Type: Water Generation: 1,
#  Pokemon: Poliwrath Type: Water Generation: 1,
#  Pokemon: Abra Type: Psychic Generation: 1,
#  Pokemon: Kadabra Type: Psychic Generation: 1,
#  Pokemon: Alakazam Type: Psychic Generation: 1,
#  Pokemon: AlakazamMega Alakazam Type: Psychic Generation: 1,
#  Pokemon: Machop Type: Fighting Generation: 1,
#  Pokemon: Machoke Type: Fighting Generation: 1,
#  Pokemon: Machamp Type: Fighting Generation: 1,
#  Pokemon: Bellsprout Type: Grass Generation: 1,
#  Pokemon: Weepinbell Type: Grass Generation: 1,
#  Pokemon: Victreebel Type: Grass Generation: 1,
#  Pokemon: Tentacool Type: Water Generation: 1,
#  Pokemon: Tentacruel Type: Water Generation: 1,
#  Pokemon: Geodude Type: Rock Generation: 1,
#  Pokemon: Graveler Type: Rock Generation: 1,
#  Pokemon: Golem Type: Rock Generation: 1,
#  Pokemon: Ponyta Type: Fire Generation: 1,
#  Pokemon: Rapidash Type: Fire Generation: 1,
#  Pokemon: Slowpoke Type: Water Generation: 1,
#  Pokemon: Slowbro Type: Water Generation: 1,
#  Pokemon: SlowbroMega Slowbro Type: Water Generation: 1,
#  Pokemon: Magnemite Type: Electric Generation: 1,
#  Pokemon: Magneton Type: Electric Generation: 1,
#  Pokemon: Farfetch'd Type: Normal Generation: 1,
#  Pokemon: Doduo Type: Normal Generation: 1,
#  Pokemon: Dodrio Type: Normal Generation: 1,
#  Pokemon: Seel Type: Water Generation: 1,
#  Pokemon: Dewgong Type: Water Generation: 1,
#  Pokemon: Grimer Type: Poison Generation: 1,
#  Pokemon: Muk Type: Poison Generation: 1,
#  Pokemon: Shellder Type: Water Generation: 1,
#  Pokemon: Cloyster Type: Water Generation: 1,
#  Pokemon: Gastly Type: Ghost Generation: 1,
#  Pokemon: Haunter Type: Ghost Generation: 1,
#  Pokemon: Gengar Type: Ghost Generation: 1,
#  Pokemon: GengarMega Gengar Type: Ghost Generation: 1,
#  Pokemon: Onix Type: Rock Generation: 1,
#  Pokemon: Drowzee Type: Psychic Generation: 1,
#  Pokemon: Hypno Type: Psychic Generation: 1,
#  Pokemon: Krabby Type: Water Generation: 1,
#  Pokemon: Kingler Type: Water Generation: 1,
#  Pokemon: Voltorb Type: Electric Generation: 1,
#  Pokemon: Electrode Type: Electric Generation: 1,
#  Pokemon: Exeggcute Type: Grass Generation: 1,
#  Pokemon: Exeggutor Type: Grass Generation: 1,
#  Pokemon: Cubone Type: Ground Generation: 1,
#  Pokemon: Marowak Type: Ground Generation: 1,
#  Pokemon: Hitmonlee Type: Fighting Generation: 1,
#  Pokemon: Hitmonchan Type: Fighting Generation: 1,
#  Pokemon: Lickitung Type: Normal Generation: 1,
#  Pokemon: Koffing Type: Poison Generation: 1,
#  Pokemon: Weezing Type: Poison Generation: 1,
#  Pokemon: Rhyhorn Type: Ground Generation: 1,
#  Pokemon: Rhydon Type: Ground Generation: 1,
#  Pokemon: Chansey Type: Normal Generation: 1,
#  Pokemon: Tangela Type: Grass Generation: 1,
#  Pokemon: Kangaskhan Type: Normal Generation: 1,
#  Pokemon: KangaskhanMega Kangaskhan Type: Normal Generation: 1,
#  Pokemon: Horsea Type: Water Generation: 1,
#  Pokemon: Seadra Type: Water Generation: 1,
#  Pokemon: Goldeen Type: Water Generation: 1,
#  Pokemon: Seaking Type: Water Generation: 1,
#  Pokemon: Staryu Type: Water Generation: 1,
#  Pokemon: Starmie Type: Water Generation: 1,
#  Pokemon: Mr. Mime Type: Psychic Generation: 1,
#  Pokemon: Scyther Type: Bug Generation: 1,
#  Pokemon: Jynx Type: Ice Generation: 1,
#  Pokemon: Electabuzz Type: Electric Generation: 1,
#  Pokemon: Magmar Type: Fire Generation: 1,
#  Pokemon: Pinsir Type: Bug Generation: 1,
#  Pokemon: PinsirMega Pinsir Type: Bug Generation: 1,
#  Pokemon: Tauros Type: Normal Generation: 1,
#  Pokemon: Magikarp Type: Water Generation: 1,
#  Pokemon: Gyarados Type: Water Generation: 1,
#  Pokemon: GyaradosMega Gyarados Type: Water Generation: 1,
#  Pokemon: Lapras Type: Water Generation: 1,
#  Pokemon: Ditto Type: Normal Generation: 1,
#  Pokemon: Eevee Type: Normal Generation: 1,
#  Pokemon: Vaporeon Type: Water Generation: 1,
#  Pokemon: Jolteon Type: Electric Generation: 1,
#  Pokemon: Flareon Type: Fire Generation: 1,
#  Pokemon: Porygon Type: Normal Generation: 1,
#  Pokemon: Omanyte Type: Rock Generation: 1,
#  Pokemon: Omastar Type: Rock Generation: 1,
#  Pokemon: Kabuto Type: Rock Generation: 1,
#  Pokemon: Kabutops Type: Rock Generation: 1,
#  Pokemon: Aerodactyl Type: Rock Generation: 1,
#  Pokemon: AerodactylMega Aerodactyl Type: Rock Generation: 1,
#  Pokemon: Snorlax Type: Normal Generation: 1,
#  Pokemon: Articuno Type: Ice Generation: 1,
#  Pokemon: Zapdos Type: Electric Generation: 1,
#  Pokemon: Moltres Type: Fire Generation: 1,
#  Pokemon: Dratini Type: Dragon Generation: 1,
#  Pokemon: Dragonair Type: Dragon Generation: 1,
#  Pokemon: Dragonite Type: Dragon Generation: 1,
#  Pokemon: Mewtwo Type: Psychic Generation: 1,
#  Pokemon: MewtwoMega Mewtwo X Type: Psychic Generation: 1,
#  Pokemon: MewtwoMega Mewtwo Y Type: Psychic Generation: 1,
#  Pokemon: Mew Type: Psychic Generation: 1,
#  Pokemon: Chikorita Type: Grass Generation: 2,
#  Pokemon: Bayleef Type: Grass Generation: 2,
#  Pokemon: Meganium Type: Grass Generation: 2,
#  Pokemon: Cyndaquil Type: Fire Generation: 2,
#  Pokemon: Quilava Type: Fire Generation: 2,
#  Pokemon: Typhlosion Type: Fire Generation: 2,
#  Pokemon: Totodile Type: Water Generation: 2,
#  Pokemon: Croconaw Type: Water Generation: 2,
#  Pokemon: Feraligatr Type: Water Generation: 2,
#  Pokemon: Sentret Type: Normal Generation: 2,
#  Pokemon: Furret Type: Normal Generation: 2,
#  Pokemon: Hoothoot Type: Normal Generation: 2,
#  Pokemon: Noctowl Type: Normal Generation: 2,
#  Pokemon: Ledyba Type: Bug Generation: 2,
#  Pokemon: Ledian Type: Bug Generation: 2,
#  Pokemon: Spinarak Type: Bug Generation: 2,
#  Pokemon: Ariados Type: Bug Generation: 2,
#  Pokemon: Crobat Type: Poison Generation: 2,
#  Pokemon: Chinchou Type: Water Generation: 2,
#  Pokemon: Lanturn Type: Water Generation: 2,
#  Pokemon: Pichu Type: Electric Generation: 2,
#  Pokemon: Cleffa Type: Fairy Generation: 2,
#  Pokemon: Igglybuff Type: Normal Generation: 2,
#  Pokemon: Togepi Type: Fairy Generation: 2,
#  Pokemon: Togetic Type: Fairy Generation: 2,
#  Pokemon: Natu Type: Psychic Generation: 2,
#  Pokemon: Xatu Type: Psychic Generation: 2,
#  Pokemon: Mareep Type: Electric Generation: 2,
#  Pokemon: Flaaffy Type: Electric Generation: 2,
#  Pokemon: Ampharos Type: Electric Generation: 2,
#  Pokemon: AmpharosMega Ampharos Type: Electric Generation: 2,
#  Pokemon: Bellossom Type: Grass Generation: 2,
#  Pokemon: Marill Type: Water Generation: 2,
#  Pokemon: Azumarill Type: Water Generation: 2,
#  Pokemon: Sudowoodo Type: Rock Generation: 2,
#  Pokemon: Politoed Type: Water Generation: 2,
#  Pokemon: Hoppip Type: Grass Generation: 2,
#  Pokemon: Skiploom Type: Grass Generation: 2,
#  Pokemon: Jumpluff Type: Grass Generation: 2,
#  Pokemon: Aipom Type: Normal Generation: 2,
#  Pokemon: Sunkern Type: Grass Generation: 2,
#  Pokemon: Sunflora Type: Grass Generation: 2,
#  Pokemon: Yanma Type: Bug Generation: 2,
#  Pokemon: Wooper Type: Water Generation: 2,
#  Pokemon: Quagsire Type: Water Generation: 2,
#  Pokemon: Espeon Type: Psychic Generation: 2,
#  Pokemon: Umbreon Type: Dark Generation: 2,
#  Pokemon: Murkrow Type: Dark Generation: 2,
#  Pokemon: Slowking Type: Water Generation: 2,
#  Pokemon: Misdreavus Type: Ghost Generation: 2,
#  Pokemon: Unown Type: Psychic Generation: 2,
#  Pokemon: Wobbuffet Type: Psychic Generation: 2,
#  Pokemon: Girafarig Type: Normal Generation: 2,
#  Pokemon: Pineco Type: Bug Generation: 2,
#  Pokemon: Forretress Type: Bug Generation: 2,
#  Pokemon: Dunsparce Type: Normal Generation: 2,
#  Pokemon: Gligar Type: Ground Generation: 2,
#  Pokemon: Steelix Type: Steel Generation: 2,
#  Pokemon: SteelixMega Steelix Type: Steel Generation: 2,
#  Pokemon: Snubbull Type: Fairy Generation: 2,
#  Pokemon: Granbull Type: Fairy Generation: 2,
#  Pokemon: Qwilfish Type: Water Generation: 2,
#  Pokemon: Scizor Type: Bug Generation: 2,
#  Pokemon: ScizorMega Scizor Type: Bug Generation: 2,
#  Pokemon: Shuckle Type: Bug Generation: 2,
#  Pokemon: Heracross Type: Bug Generation: 2,
#  Pokemon: HeracrossMega Heracross Type: Bug Generation: 2,
#  Pokemon: Sneasel Type: Dark Generation: 2,
#  Pokemon: Teddiursa Type: Normal Generation: 2,
#  Pokemon: Ursaring Type: Normal Generation: 2,
#  Pokemon: Slugma Type: Fire Generation: 2,
#  Pokemon: Magcargo Type: Fire Generation: 2,
#  Pokemon: Swinub Type: Ice Generation: 2,
#  Pokemon: Piloswine Type: Ice Generation: 2,
#  Pokemon: Corsola Type: Water Generation: 2,
#  Pokemon: Remoraid Type: Water Generation: 2,
#  Pokemon: Octillery Type: Water Generation: 2,
#  Pokemon: Delibird Type: Ice Generation: 2,
#  Pokemon: Mantine Type: Water Generation: 2,
#  Pokemon: Skarmory Type: Steel Generation: 2,
#  Pokemon: Houndour Type: Dark Generation: 2,
#  Pokemon: Houndoom Type: Dark Generation: 2,
#  Pokemon: HoundoomMega Houndoom Type: Dark Generation: 2,
#  Pokemon: Kingdra Type: Water Generation: 2,
#  Pokemon: Phanpy Type: Ground Generation: 2,
#  Pokemon: Donphan Type: Ground Generation: 2,
#  Pokemon: Porygon2 Type: Normal Generation: 2,
#  Pokemon: Stantler Type: Normal Generation: 2,
#  Pokemon: Smeargle Type: Normal Generation: 2,
#  Pokemon: Tyrogue Type: Fighting Generation: 2,
#  Pokemon: Hitmontop Type: Fighting Generation: 2,
#  Pokemon: Smoochum Type: Ice Generation: 2,
#  Pokemon: Elekid Type: Electric Generation: 2,
#  Pokemon: Magby Type: Fire Generation: 2,
#  Pokemon: Miltank Type: Normal Generation: 2,
#  Pokemon: Blissey Type: Normal Generation: 2,
#  Pokemon: Raikou Type: Electric Generation: 2,
#  Pokemon: Entei Type: Fire Generation: 2,
#  Pokemon: Suicune Type: Water Generation: 2,
#  Pokemon: Larvitar Type: Rock Generation: 2,
#  Pokemon: Pupitar Type: Rock Generation: 2,
#  Pokemon: Tyranitar Type: Rock Generation: 2,
#  Pokemon: TyranitarMega Tyranitar Type: Rock Generation: 2,
#  Pokemon: Lugia Type: Psychic Generation: 2,
#  Pokemon: Ho-oh Type: Fire Generation: 2,
#  Pokemon: Celebi Type: Psychic Generation: 2,
#  Pokemon: Treecko Type: Grass Generation: 3,
#  Pokemon: Grovyle Type: Grass Generation: 3,
#  Pokemon: Sceptile Type: Grass Generation: 3,
#  Pokemon: SceptileMega Sceptile Type: Grass Generation: 3,
#  Pokemon: Torchic Type: Fire Generation: 3,
#  Pokemon: Combusken Type: Fire Generation: 3,
#  Pokemon: Blaziken Type: Fire Generation: 3,
#  Pokemon: BlazikenMega Blaziken Type: Fire Generation: 3,
#  Pokemon: Mudkip Type: Water Generation: 3,
#  Pokemon: Marshtomp Type: Water Generation: 3,
#  Pokemon: Swampert Type: Water Generation: 3,
#  Pokemon: SwampertMega Swampert Type: Water Generation: 3,
#  Pokemon: Poochyena Type: Dark Generation: 3,
#  Pokemon: Mightyena Type: Dark Generation: 3,
#  Pokemon: Zigzagoon Type: Normal Generation: 3,
#  Pokemon: Linoone Type: Normal Generation: 3,
#  Pokemon: Wurmple Type: Bug Generation: 3,
#  Pokemon: Silcoon Type: Bug Generation: 3,
#  Pokemon: Beautifly Type: Bug Generation: 3,
#  Pokemon: Cascoon Type: Bug Generation: 3,
#  Pokemon: Dustox Type: Bug Generation: 3,
#  Pokemon: Lotad Type: Water Generation: 3,
#  Pokemon: Lombre Type: Water Generation: 3,
#  Pokemon: Ludicolo Type: Water Generation: 3,
#  Pokemon: Seedot Type: Grass Generation: 3,
#  Pokemon: Nuzleaf Type: Grass Generation: 3,
#  Pokemon: Shiftry Type: Grass Generation: 3,
#  Pokemon: Taillow Type: Normal Generation: 3,
#  Pokemon: Swellow Type: Normal Generation: 3,
#  Pokemon: Wingull Type: Water Generation: 3,
#  Pokemon: Pelipper Type: Water Generation: 3,
#  Pokemon: Ralts Type: Psychic Generation: 3,
#  Pokemon: Kirlia Type: Psychic Generation: 3,
#  Pokemon: Gardevoir Type: Psychic Generation: 3,
#  Pokemon: GardevoirMega Gardevoir Type: Psychic Generation: 3,
#  Pokemon: Surskit Type: Bug Generation: 3,
#  Pokemon: Masquerain Type: Bug Generation: 3,
#  Pokemon: Shroomish Type: Grass Generation: 3,
#  Pokemon: Breloom Type: Grass Generation: 3,
#  Pokemon: Slakoth Type: Normal Generation: 3,
#  Pokemon: Vigoroth Type: Normal Generation: 3,
#  Pokemon: Slaking Type: Normal Generation: 3,
#  Pokemon: Nincada Type: Bug Generation: 3,
#  Pokemon: Ninjask Type: Bug Generation: 3,
#  Pokemon: Shedinja Type: Bug Generation: 3,
#  Pokemon: Whismur Type: Normal Generation: 3,
#  Pokemon: Loudred Type: Normal Generation: 3,
#  Pokemon: Exploud Type: Normal Generation: 3,
#  Pokemon: Makuhita Type: Fighting Generation: 3,
#  Pokemon: Hariyama Type: Fighting Generation: 3,
#  Pokemon: Azurill Type: Normal Generation: 3,
#  Pokemon: Nosepass Type: Rock Generation: 3,
#  Pokemon: Skitty Type: Normal Generation: 3,
#  Pokemon: Delcatty Type: Normal Generation: 3,
#  Pokemon: Sableye Type: Dark Generation: 3,
#  Pokemon: SableyeMega Sableye Type: Dark Generation: 3,
#  Pokemon: Mawile Type: Steel Generation: 3,
#  Pokemon: MawileMega Mawile Type: Steel Generation: 3,
#  Pokemon: Aron Type: Steel Generation: 3,
#  Pokemon: Lairon Type: Steel Generation: 3,
#  Pokemon: Aggron Type: Steel Generation: 3,
#  Pokemon: AggronMega Aggron Type: Steel Generation: 3,
#  Pokemon: Meditite Type: Fighting Generation: 3,
#  Pokemon: Medicham Type: Fighting Generation: 3,
#  Pokemon: MedichamMega Medicham Type: Fighting Generation: 3,
#  Pokemon: Electrike Type: Electric Generation: 3,
#  Pokemon: Manectric Type: Electric Generation: 3,
#  Pokemon: ManectricMega Manectric Type: Electric Generation: 3,
#  Pokemon: Plusle Type: Electric Generation: 3,
#  Pokemon: Minun Type: Electric Generation: 3,
#  Pokemon: Volbeat Type: Bug Generation: 3,
#  Pokemon: Illumise Type: Bug Generation: 3,
#  Pokemon: Roselia Type: Grass Generation: 3,
#  Pokemon: Gulpin Type: Poison Generation: 3,
#  Pokemon: Swalot Type: Poison Generation: 3,
#  Pokemon: Carvanha Type: Water Generation: 3,
#  Pokemon: Sharpedo Type: Water Generation: 3,
#  Pokemon: SharpedoMega Sharpedo Type: Water Generation: 3,
#  Pokemon: Wailmer Type: Water Generation: 3,
#  Pokemon: Wailord Type: Water Generation: 3,
#  Pokemon: Numel Type: Fire Generation: 3,
#  Pokemon: Camerupt Type: Fire Generation: 3,
#  Pokemon: CameruptMega Camerupt Type: Fire Generation: 3,
#  Pokemon: Torkoal Type: Fire Generation: 3,
#  Pokemon: Spoink Type: Psychic Generation: 3,
#  Pokemon: Grumpig Type: Psychic Generation: 3,
#  Pokemon: Spinda Type: Normal Generation: 3,
#  Pokemon: Trapinch Type: Ground Generation: 3,
#  Pokemon: Vibrava Type: Ground Generation: 3,
#  Pokemon: Flygon Type: Ground Generation: 3,
#  Pokemon: Cacnea Type: Grass Generation: 3,
#  Pokemon: Cacturne Type: Grass Generation: 3,
#  Pokemon: Swablu Type: Normal Generation: 3,
#  Pokemon: Altaria Type: Dragon Generation: 3,
#  Pokemon: AltariaMega Altaria Type: Dragon Generation: 3,
#  Pokemon: Zangoose Type: Normal Generation: 3,
#  Pokemon: Seviper Type: Poison Generation: 3,
#  Pokemon: Lunatone Type: Rock Generation: 3,
#  Pokemon: Solrock Type: Rock Generation: 3,
#  Pokemon: Barboach Type: Water Generation: 3,
#  Pokemon: Whiscash Type: Water Generation: 3,
#  Pokemon: Corphish Type: Water Generation: 3,
#  Pokemon: Crawdaunt Type: Water Generation: 3,
#  Pokemon: Baltoy Type: Ground Generation: 3,
#  Pokemon: Claydol Type: Ground Generation: 3,
#  Pokemon: Lileep Type: Rock Generation: 3,
#  Pokemon: Cradily Type: Rock Generation: 3,
#  Pokemon: Anorith Type: Rock Generation: 3,
#  Pokemon: Armaldo Type: Rock Generation: 3,
#  Pokemon: Feebas Type: Water Generation: 3,
#  Pokemon: Milotic Type: Water Generation: 3,
#  Pokemon: Castform Type: Normal Generation: 3,
#  Pokemon: Kecleon Type: Normal Generation: 3,
#  Pokemon: Shuppet Type: Ghost Generation: 3,
#  Pokemon: Banette Type: Ghost Generation: 3,
#  Pokemon: BanetteMega Banette Type: Ghost Generation: 3,
#  Pokemon: Duskull Type: Ghost Generation: 3,
#  Pokemon: Dusclops Type: Ghost Generation: 3,
#  Pokemon: Tropius Type: Grass Generation: 3,
#  Pokemon: Chimecho Type: Psychic Generation: 3,
#  Pokemon: Absol Type: Dark Generation: 3,
#  Pokemon: AbsolMega Absol Type: Dark Generation: 3,
#  Pokemon: Wynaut Type: Psychic Generation: 3,
#  Pokemon: Snorunt Type: Ice Generation: 3,
#  Pokemon: Glalie Type: Ice Generation: 3,
#  Pokemon: GlalieMega Glalie Type: Ice Generation: 3,
#  Pokemon: Spheal Type: Ice Generation: 3,
#  Pokemon: Sealeo Type: Ice Generation: 3,
#  Pokemon: Walrein Type: Ice Generation: 3,
#  Pokemon: Clamperl Type: Water Generation: 3,
#  Pokemon: Huntail Type: Water Generation: 3,
#  Pokemon: Gorebyss Type: Water Generation: 3,
#  Pokemon: Relicanth Type: Water Generation: 3,
#  Pokemon: Luvdisc Type: Water Generation: 3,
#  Pokemon: Bagon Type: Dragon Generation: 3,
#  Pokemon: Shelgon Type: Dragon Generation: 3,
#  Pokemon: Salamence Type: Dragon Generation: 3,
#  Pokemon: SalamenceMega Salamence Type: Dragon Generation: 3,
#  Pokemon: Beldum Type: Steel Generation: 3,
#  Pokemon: Metang Type: Steel Generation: 3,
#  Pokemon: Metagross Type: Steel Generation: 3,
#  Pokemon: MetagrossMega Metagross Type: Steel Generation: 3,
#  Pokemon: Regirock Type: Rock Generation: 3,
#  Pokemon: Regice Type: Ice Generation: 3,
#  Pokemon: Registeel Type: Steel Generation: 3,
#  Pokemon: Latias Type: Dragon Generation: 3,
#  Pokemon: LatiasMega Latias Type: Dragon Generation: 3,
#  Pokemon: Latios Type: Dragon Generation: 3,
#  Pokemon: LatiosMega Latios Type: Dragon Generation: 3,
#  Pokemon: Kyogre Type: Water Generation: 3,
#  Pokemon: KyogrePrimal Kyogre Type: Water Generation: 3,
#  Pokemon: Groudon Type: Ground Generation: 3,
#  Pokemon: GroudonPrimal Groudon Type: Ground Generation: 3,
#  Pokemon: Rayquaza Type: Dragon Generation: 3,
#  Pokemon: RayquazaMega Rayquaza Type: Dragon Generation: 3,
#  Pokemon: Jirachi Type: Steel Generation: 3,
#  Pokemon: DeoxysNormal Forme Type: Psychic Generation: 3,
#  Pokemon: DeoxysAttack Forme Type: Psychic Generation: 3,
#  Pokemon: DeoxysDefense Forme Type: Psychic Generation: 3,
#  Pokemon: DeoxysSpeed Forme Type: Psychic Generation: 3,
#  Pokemon: Turtwig Type: Grass Generation: 4,
#  Pokemon: Grotle Type: Grass Generation: 4,
#  Pokemon: Torterra Type: Grass Generation: 4,
#  Pokemon: Chimchar Type: Fire Generation: 4,
#  Pokemon: Monferno Type: Fire Generation: 4,
#  Pokemon: Infernape Type: Fire Generation: 4,
#  Pokemon: Piplup Type: Water Generation: 4,
#  Pokemon: Prinplup Type: Water Generation: 4,
#  Pokemon: Empoleon Type: Water Generation: 4,
#  Pokemon: Starly Type: Normal Generation: 4,
#  Pokemon: Staravia Type: Normal Generation: 4,
#  Pokemon: Staraptor Type: Normal Generation: 4,
#  Pokemon: Bidoof Type: Normal Generation: 4,
#  Pokemon: Bibarel Type: Normal Generation: 4,
#  Pokemon: Kricketot Type: Bug Generation: 4,
#  Pokemon: Kricketune Type: Bug Generation: 4,
#  Pokemon: Shinx Type: Electric Generation: 4,
#  Pokemon: Luxio Type: Electric Generation: 4,
#  Pokemon: Luxray Type: Electric Generation: 4,
#  Pokemon: Budew Type: Grass Generation: 4,
#  Pokemon: Roserade Type: Grass Generation: 4,
#  Pokemon: Cranidos Type: Rock Generation: 4,
#  Pokemon: Rampardos Type: Rock Generation: 4,
#  Pokemon: Shieldon Type: Rock Generation: 4,
#  Pokemon: Bastiodon Type: Rock Generation: 4,
#  Pokemon: Burmy Type: Bug Generation: 4,
#  Pokemon: WormadamPlant Cloak Type: Bug Generation: 4,
#  Pokemon: WormadamSandy Cloak Type: Bug Generation: 4,
#  Pokemon: WormadamTrash Cloak Type: Bug Generation: 4,
#  Pokemon: Mothim Type: Bug Generation: 4,
#  Pokemon: Combee Type: Bug Generation: 4,
#  Pokemon: Vespiquen Type: Bug Generation: 4,
#  Pokemon: Pachirisu Type: Electric Generation: 4,
#  Pokemon: Buizel Type: Water Generation: 4,
#  Pokemon: Floatzel Type: Water Generation: 4,
#  Pokemon: Cherubi Type: Grass Generation: 4,
#  Pokemon: Cherrim Type: Grass Generation: 4,
#  Pokemon: Shellos Type: Water Generation: 4,
#  Pokemon: Gastrodon Type: Water Generation: 4,
#  Pokemon: Ambipom Type: Normal Generation: 4,
#  Pokemon: Drifloon Type: Ghost Generation: 4,
#  Pokemon: Drifblim Type: Ghost Generation: 4,
#  Pokemon: Buneary Type: Normal Generation: 4,
#  Pokemon: Lopunny Type: Normal Generation: 4,
#  Pokemon: LopunnyMega Lopunny Type: Normal Generation: 4,
#  Pokemon: Mismagius Type: Ghost Generation: 4,
#  Pokemon: Honchkrow Type: Dark Generation: 4,
#  Pokemon: Glameow Type: Normal Generation: 4,
#  Pokemon: Purugly Type: Normal Generation: 4,
#  Pokemon: Chingling Type: Psychic Generation: 4,
#  Pokemon: Stunky Type: Poison Generation: 4,
#  Pokemon: Skuntank Type: Poison Generation: 4,
#  Pokemon: Bronzor Type: Steel Generation: 4,
#  Pokemon: Bronzong Type: Steel Generation: 4,
#  Pokemon: Bonsly Type: Rock Generation: 4,
#  Pokemon: Mime Jr. Type: Psychic Generation: 4,
#  Pokemon: Happiny Type: Normal Generation: 4,
#  Pokemon: Chatot Type: Normal Generation: 4,
#  Pokemon: Spiritomb Type: Ghost Generation: 4,
#  Pokemon: Gible Type: Dragon Generation: 4,
#  Pokemon: Gabite Type: Dragon Generation: 4,
#  Pokemon: Garchomp Type: Dragon Generation: 4,
#  Pokemon: GarchompMega Garchomp Type: Dragon Generation: 4,
#  Pokemon: Munchlax Type: Normal Generation: 4,
#  Pokemon: Riolu Type: Fighting Generation: 4,
#  Pokemon: Lucario Type: Fighting Generation: 4,
#  Pokemon: LucarioMega Lucario Type: Fighting Generation: 4,
#  Pokemon: Hippopotas Type: Ground Generation: 4,
#  Pokemon: Hippowdon Type: Ground Generation: 4,
#  Pokemon: Skorupi Type: Poison Generation: 4,
#  Pokemon: Drapion Type: Poison Generation: 4,
#  Pokemon: Croagunk Type: Poison Generation: 4,
#  Pokemon: Toxicroak Type: Poison Generation: 4,
#  Pokemon: Carnivine Type: Grass Generation: 4,
#  Pokemon: Finneon Type: Water Generation: 4,
#  Pokemon: Lumineon Type: Water Generation: 4,
#  Pokemon: Mantyke Type: Water Generation: 4,
#  Pokemon: Snover Type: Grass Generation: 4,
#  Pokemon: Abomasnow Type: Grass Generation: 4,
#  Pokemon: AbomasnowMega Abomasnow Type: Grass Generation: 4,
#  Pokemon: Weavile Type: Dark Generation: 4,
#  Pokemon: Magnezone Type: Electric Generation: 4,
#  Pokemon: Lickilicky Type: Normal Generation: 4,
#  Pokemon: Rhyperior Type: Ground Generation: 4,
#  Pokemon: Tangrowth Type: Grass Generation: 4,
#  Pokemon: Electivire Type: Electric Generation: 4,
#  Pokemon: Magmortar Type: Fire Generation: 4,
#  Pokemon: Togekiss Type: Fairy Generation: 4,
#  Pokemon: Yanmega Type: Bug Generation: 4,
#  Pokemon: Leafeon Type: Grass Generation: 4,
#  Pokemon: Glaceon Type: Ice Generation: 4,
#  Pokemon: Gliscor Type: Ground Generation: 4,
#  Pokemon: Mamoswine Type: Ice Generation: 4,
#  Pokemon: Porygon-Z Type: Normal Generation: 4,
#  Pokemon: Gallade Type: Psychic Generation: 4,
#  Pokemon: GalladeMega Gallade Type: Psychic Generation: 4,
#  Pokemon: Probopass Type: Rock Generation: 4,
#  Pokemon: Dusknoir Type: Ghost Generation: 4,
#  Pokemon: Froslass Type: Ice Generation: 4,
#  Pokemon: Rotom Type: Electric Generation: 4,
#  Pokemon: RotomHeat Rotom Type: Electric Generation: 4,
#  Pokemon: RotomWash Rotom Type: Electric Generation: 4,
#  Pokemon: RotomFrost Rotom Type: Electric Generation: 4,
#  Pokemon: RotomFan Rotom Type: Electric Generation: 4,
#  Pokemon: RotomMow Rotom Type: Electric Generation: 4,
#  Pokemon: Uxie Type: Psychic Generation: 4,
#  Pokemon: Mesprit Type: Psychic Generation: 4,
#  Pokemon: Azelf Type: Psychic Generation: 4,
#  Pokemon: Dialga Type: Steel Generation: 4,
#  Pokemon: Palkia Type: Water Generation: 4,
#  Pokemon: Heatran Type: Fire Generation: 4,
#  Pokemon: Regigigas Type: Normal Generation: 4,
#  Pokemon: GiratinaAltered Forme Type: Ghost Generation: 4,
#  Pokemon: GiratinaOrigin Forme Type: Ghost Generation: 4,
#  Pokemon: Cresselia Type: Psychic Generation: 4,
#  Pokemon: Phione Type: Water Generation: 4,
#  Pokemon: Manaphy Type: Water Generation: 4,
#  Pokemon: Darkrai Type: Dark Generation: 4,
#  Pokemon: ShayminLand Forme Type: Grass Generation: 4,
#  Pokemon: ShayminSky Forme Type: Grass Generation: 4,
#  Pokemon: Arceus Type: Normal Generation: 4,
#  Pokemon: Victini Type: Psychic Generation: 5,
#  Pokemon: Snivy Type: Grass Generation: 5,
#  Pokemon: Servine Type: Grass Generation: 5,
#  Pokemon: Serperior Type: Grass Generation: 5,
#  Pokemon: Tepig Type: Fire Generation: 5,
#  Pokemon: Pignite Type: Fire Generation: 5,
#  Pokemon: Emboar Type: Fire Generation: 5,
#  Pokemon: Oshawott Type: Water Generation: 5,
#  Pokemon: Dewott Type: Water Generation: 5,
#  Pokemon: Samurott Type: Water Generation: 5,
#  Pokemon: Patrat Type: Normal Generation: 5,
#  Pokemon: Watchog Type: Normal Generation: 5,
#  Pokemon: Lillipup Type: Normal Generation: 5,
#  Pokemon: Herdier Type: Normal Generation: 5,
#  Pokemon: Stoutland Type: Normal Generation: 5,
#  Pokemon: Purrloin Type: Dark Generation: 5,
#  Pokemon: Liepard Type: Dark Generation: 5,
#  Pokemon: Pansage Type: Grass Generation: 5,
#  Pokemon: Simisage Type: Grass Generation: 5,
#  Pokemon: Pansear Type: Fire Generation: 5,
#  Pokemon: Simisear Type: Fire Generation: 5,
#  Pokemon: Panpour Type: Water Generation: 5,
#  Pokemon: Simipour Type: Water Generation: 5,
#  Pokemon: Munna Type: Psychic Generation: 5,
#  Pokemon: Musharna Type: Psychic Generation: 5,
#  Pokemon: Pidove Type: Normal Generation: 5,
#  Pokemon: Tranquill Type: Normal Generation: 5,
#  Pokemon: Unfezant Type: Normal Generation: 5,
#  Pokemon: Blitzle Type: Electric Generation: 5,
#  Pokemon: Zebstrika Type: Electric Generation: 5,
#  Pokemon: Roggenrola Type: Rock Generation: 5,
#  Pokemon: Boldore Type: Rock Generation: 5,
#  Pokemon: Gigalith Type: Rock Generation: 5,
#  Pokemon: Woobat Type: Psychic Generation: 5,
#  Pokemon: Swoobat Type: Psychic Generation: 5,
#  Pokemon: Drilbur Type: Ground Generation: 5,
#  Pokemon: Excadrill Type: Ground Generation: 5,
#  Pokemon: Audino Type: Normal Generation: 5,
#  Pokemon: AudinoMega Audino Type: Normal Generation: 5,
#  Pokemon: Timburr Type: Fighting Generation: 5,
#  Pokemon: Gurdurr Type: Fighting Generation: 5,
#  Pokemon: Conkeldurr Type: Fighting Generation: 5,
#  Pokemon: Tympole Type: Water Generation: 5,
#  Pokemon: Palpitoad Type: Water Generation: 5,
#  Pokemon: Seismitoad Type: Water Generation: 5,
#  Pokemon: Throh Type: Fighting Generation: 5,
#  Pokemon: Sawk Type: Fighting Generation: 5,
#  Pokemon: Sewaddle Type: Bug Generation: 5,
#  Pokemon: Swadloon Type: Bug Generation: 5,
#  Pokemon: Leavanny Type: Bug Generation: 5,
#  Pokemon: Venipede Type: Bug Generation: 5,
#  Pokemon: Whirlipede Type: Bug Generation: 5,
#  Pokemon: Scolipede Type: Bug Generation: 5,
#  Pokemon: Cottonee Type: Grass Generation: 5,
#  Pokemon: Whimsicott Type: Grass Generation: 5,
#  Pokemon: Petilil Type: Grass Generation: 5,
#  Pokemon: Lilligant Type: Grass Generation: 5,
#  Pokemon: Basculin Type: Water Generation: 5,
#  Pokemon: Sandile Type: Ground Generation: 5,
#  Pokemon: Krokorok Type: Ground Generation: 5,
#  Pokemon: Krookodile Type: Ground Generation: 5,
#  Pokemon: Darumaka Type: Fire Generation: 5,
#  Pokemon: DarmanitanStandard Mode Type: Fire Generation: 5,
#  Pokemon: DarmanitanZen Mode Type: Fire Generation: 5,
#  Pokemon: Maractus Type: Grass Generation: 5,
#  Pokemon: Dwebble Type: Bug Generation: 5,
#  Pokemon: Crustle Type: Bug Generation: 5,
#  Pokemon: Scraggy Type: Dark Generation: 5,
#  Pokemon: Scrafty Type: Dark Generation: 5,
#  Pokemon: Sigilyph Type: Psychic Generation: 5,
#  Pokemon: Yamask Type: Ghost Generation: 5,
#  Pokemon: Cofagrigus Type: Ghost Generation: 5,
#  Pokemon: Tirtouga Type: Water Generation: 5,
#  Pokemon: Carracosta Type: Water Generation: 5,
#  Pokemon: Archen Type: Rock Generation: 5,
#  Pokemon: Archeops Type: Rock Generation: 5,
#  Pokemon: Trubbish Type: Poison Generation: 5,
#  Pokemon: Garbodor Type: Poison Generation: 5,
#  Pokemon: Zorua Type: Dark Generation: 5,
#  Pokemon: Zoroark Type: Dark Generation: 5,
#  Pokemon: Minccino Type: Normal Generation: 5,
#  Pokemon: Cinccino Type: Normal Generation: 5,
#  Pokemon: Gothita Type: Psychic Generation: 5,
#  Pokemon: Gothorita Type: Psychic Generation: 5,
#  Pokemon: Gothitelle Type: Psychic Generation: 5,
#  Pokemon: Solosis Type: Psychic Generation: 5,
#  Pokemon: Duosion Type: Psychic Generation: 5,
#  Pokemon: Reuniclus Type: Psychic Generation: 5,
#  Pokemon: Ducklett Type: Water Generation: 5,
#  Pokemon: Swanna Type: Water Generation: 5,
#  Pokemon: Vanillite Type: Ice Generation: 5,
#  Pokemon: Vanillish Type: Ice Generation: 5,
#  Pokemon: Vanilluxe Type: Ice Generation: 5,
#  Pokemon: Deerling Type: Normal Generation: 5,
#  Pokemon: Sawsbuck Type: Normal Generation: 5,
#  Pokemon: Emolga Type: Electric Generation: 5,
#  Pokemon: Karrablast Type: Bug Generation: 5,
#  Pokemon: Escavalier Type: Bug Generation: 5,
#  Pokemon: Foongus Type: Grass Generation: 5,
#  Pokemon: Amoonguss Type: Grass Generation: 5,
#  Pokemon: Frillish Type: Water Generation: 5,
#  Pokemon: Jellicent Type: Water Generation: 5,
#  Pokemon: Alomomola Type: Water Generation: 5,
#  Pokemon: Joltik Type: Bug Generation: 5,
#  Pokemon: Galvantula Type: Bug Generation: 5,
#  Pokemon: Ferroseed Type: Grass Generation: 5,
#  Pokemon: Ferrothorn Type: Grass Generation: 5,
#  Pokemon: Klink Type: Steel Generation: 5,
#  Pokemon: Klang Type: Steel Generation: 5,
#  Pokemon: Klinklang Type: Steel Generation: 5,
#  Pokemon: Tynamo Type: Electric Generation: 5,
#  Pokemon: Eelektrik Type: Electric Generation: 5,
#  Pokemon: Eelektross Type: Electric Generation: 5,
#  Pokemon: Elgyem Type: Psychic Generation: 5,
#  Pokemon: Beheeyem Type: Psychic Generation: 5,
#  Pokemon: Litwick Type: Ghost Generation: 5,
#  Pokemon: Lampent Type: Ghost Generation: 5,
#  Pokemon: Chandelure Type: Ghost Generation: 5,
#  Pokemon: Axew Type: Dragon Generation: 5,
#  Pokemon: Fraxure Type: Dragon Generation: 5,
#  Pokemon: Haxorus Type: Dragon Generation: 5,
#  Pokemon: Cubchoo Type: Ice Generation: 5,
#  Pokemon: Beartic Type: Ice Generation: 5,
#  Pokemon: Cryogonal Type: Ice Generation: 5,
#  Pokemon: Shelmet Type: Bug Generation: 5,
#  Pokemon: Accelgor Type: Bug Generation: 5,
#  Pokemon: Stunfisk Type: Ground Generation: 5,
#  Pokemon: Mienfoo Type: Fighting Generation: 5,
#  Pokemon: Mienshao Type: Fighting Generation: 5,
#  Pokemon: Druddigon Type: Dragon Generation: 5,
#  Pokemon: Golett Type: Ground Generation: 5,
#  Pokemon: Golurk Type: Ground Generation: 5,
#  Pokemon: Pawniard Type: Dark Generation: 5,
#  Pokemon: Bisharp Type: Dark Generation: 5,
#  Pokemon: Bouffalant Type: Normal Generation: 5,
#  Pokemon: Rufflet Type: Normal Generation: 5,
#  Pokemon: Braviary Type: Normal Generation: 5,
#  Pokemon: Vullaby Type: Dark Generation: 5,
#  Pokemon: Mandibuzz Type: Dark Generation: 5,
#  Pokemon: Heatmor Type: Fire Generation: 5,
#  Pokemon: Durant Type: Bug Generation: 5,
#  Pokemon: Deino Type: Dark Generation: 5,
#  Pokemon: Zweilous Type: Dark Generation: 5,
#  Pokemon: Hydreigon Type: Dark Generation: 5,
#  Pokemon: Larvesta Type: Bug Generation: 5,
#  Pokemon: Volcarona Type: Bug Generation: 5,
#  Pokemon: Cobalion Type: Steel Generation: 5,
#  Pokemon: Terrakion Type: Rock Generation: 5,
#  Pokemon: Virizion Type: Grass Generation: 5,
#  Pokemon: TornadusIncarnate Forme Type: Flying Generation: 5,
#  Pokemon: TornadusTherian Forme Type: Flying Generation: 5,
#  Pokemon: ThundurusIncarnate Forme Type: Electric Generation: 5,
#  Pokemon: ThundurusTherian Forme Type: Electric Generation: 5,
#  Pokemon: Reshiram Type: Dragon Generation: 5,
#  Pokemon: Zekrom Type: Dragon Generation: 5,
#  Pokemon: LandorusIncarnate Forme Type: Ground Generation: 5,
#  Pokemon: LandorusTherian Forme Type: Ground Generation: 5,
#  Pokemon: Kyurem Type: Dragon Generation: 5,
#  Pokemon: KyuremBlack Kyurem Type: Dragon Generation: 5,
#  Pokemon: KyuremWhite Kyurem Type: Dragon Generation: 5,
#  Pokemon: KeldeoOrdinary Forme Type: Water Generation: 5,
#  Pokemon: KeldeoResolute Forme Type: Water Generation: 5,
#  Pokemon: MeloettaAria Forme Type: Normal Generation: 5,
#  Pokemon: MeloettaPirouette Forme Type: Normal Generation: 5,
#  Pokemon: Genesect Type: Bug Generation: 5,
#  Pokemon: Chespin Type: Grass Generation: 6,
#  Pokemon: Quilladin Type: Grass Generation: 6,
#  Pokemon: Chesnaught Type: Grass Generation: 6,
#  Pokemon: Fennekin Type: Fire Generation: 6,
#  Pokemon: Braixen Type: Fire Generation: 6,
#  Pokemon: Delphox Type: Fire Generation: 6,
#  Pokemon: Froakie Type: Water Generation: 6,
#  Pokemon: Frogadier Type: Water Generation: 6,
#  Pokemon: Greninja Type: Water Generation: 6,
#  Pokemon: Bunnelby Type: Normal Generation: 6,
#  Pokemon: Diggersby Type: Normal Generation: 6,
#  Pokemon: Fletchling Type: Normal Generation: 6,
#  Pokemon: Fletchinder Type: Fire Generation: 6,
#  Pokemon: Talonflame Type: Fire Generation: 6,
#  Pokemon: Scatterbug Type: Bug Generation: 6,
#  Pokemon: Spewpa Type: Bug Generation: 6,
#  Pokemon: Vivillon Type: Bug Generation: 6,
#  Pokemon: Litleo Type: Fire Generation: 6,
#  Pokemon: Pyroar Type: Fire Generation: 6,
#  Pokemon: Flabébé Type: Fairy Generation: 6,
#  Pokemon: Floette Type: Fairy Generation: 6,
#  Pokemon: Florges Type: Fairy Generation: 6,
#  Pokemon: Skiddo Type: Grass Generation: 6,
#  Pokemon: Gogoat Type: Grass Generation: 6,
#  Pokemon: Pancham Type: Fighting Generation: 6,
#  Pokemon: Pangoro Type: Fighting Generation: 6,
#  Pokemon: Furfrou Type: Normal Generation: 6,
#  Pokemon: Espurr Type: Psychic Generation: 6,
#  Pokemon: MeowsticMale Type: Psychic Generation: 6,
#  Pokemon: MeowsticFemale Type: Psychic Generation: 6,
#  Pokemon: Honedge Type: Steel Generation: 6,
#  Pokemon: Doublade Type: Steel Generation: 6,
#  Pokemon: AegislashBlade Forme Type: Steel Generation: 6,
#  Pokemon: AegislashShield Forme Type: Steel Generation: 6,
#  Pokemon: Spritzee Type: Fairy Generation: 6,
#  Pokemon: Aromatisse Type: Fairy Generation: 6,
#  Pokemon: Swirlix Type: Fairy Generation: 6,
#  Pokemon: Slurpuff Type: Fairy Generation: 6,
#  Pokemon: Inkay Type: Dark Generation: 6,
#  Pokemon: Malamar Type: Dark Generation: 6,
#  Pokemon: Binacle Type: Rock Generation: 6,
#  Pokemon: Barbaracle Type: Rock Generation: 6,
#  Pokemon: Skrelp Type: Poison Generation: 6,
#  Pokemon: Dragalge Type: Poison Generation: 6,
#  Pokemon: Clauncher Type: Water Generation: 6,
#  Pokemon: Clawitzer Type: Water Generation: 6,
#  Pokemon: Helioptile Type: Electric Generation: 6,
#  Pokemon: Heliolisk Type: Electric Generation: 6,
#  Pokemon: Tyrunt Type: Rock Generation: 6,
#  Pokemon: Tyrantrum Type: Rock Generation: 6,
#  Pokemon: Amaura Type: Rock Generation: 6,
#  Pokemon: Aurorus Type: Rock Generation: 6,
#  Pokemon: Sylveon Type: Fairy Generation: 6,
#  Pokemon: Hawlucha Type: Fighting Generation: 6,
#  Pokemon: Dedenne Type: Electric Generation: 6,
#  Pokemon: Carbink Type: Rock Generation: 6,
#  Pokemon: Goomy Type: Dragon Generation: 6,
#  Pokemon: Sliggoo Type: Dragon Generation: 6,
#  Pokemon: Goodra Type: Dragon Generation: 6,
#  Pokemon: Klefki Type: Steel Generation: 6,
#  Pokemon: Phantump Type: Ghost Generation: 6,
#  Pokemon: Trevenant Type: Ghost Generation: 6,
#  Pokemon: PumpkabooAverage Size Type: Ghost Generation: 6,
#  Pokemon: PumpkabooSmall Size Type: Ghost Generation: 6,
#  Pokemon: PumpkabooLarge Size Type: Ghost Generation: 6,
#  Pokemon: PumpkabooSuper Size Type: Ghost Generation: 6,
#  Pokemon: GourgeistAverage Size Type: Ghost Generation: 6,
#  Pokemon: GourgeistSmall Size Type: Ghost Generation: 6,
#  Pokemon: GourgeistLarge Size Type: Ghost Generation: 6,
#  Pokemon: GourgeistSuper Size Type: Ghost Generation: 6,
#  Pokemon: Bergmite Type: Ice Generation: 6,
#  Pokemon: Avalugg Type: Ice Generation: 6,
#  Pokemon: Noibat Type: Flying Generation: 6,
#  Pokemon: Noivern Type: Flying Generation: 6,
#  Pokemon: Xerneas Type: Fairy Generation: 6,
#  Pokemon: Yveltal Type: Dark Generation: 6,
#  Pokemon: Zygarde50% Forme Type: Dragon Generation: 6,
#  Pokemon: Diancie Type: Rock Generation: 6,
#  Pokemon: DiancieMega Diancie Type: Rock Generation: 6,
#  Pokemon: HoopaHoopa Confined Type: Psychic Generation: 6,
#  Pokemon: HoopaHoopa Unbound Type: Psychic Generation: 6,
#  Pokemon: Volcanion Type: Fire Generation: 6]

# %% [markdown]
# ## Combine all of the things we learned
# The following code block uses objects, lists, conditions, loops, methods. In short, everything you learned so far.
#
# ### Exercise
# Clone to your repository and change the following parts:
# 1. Let him find your favorite Pokemon
# 2. Print the name and the attack value of the Pokemon with the strongest attack
# 3. Make a list of all of the Pokemon of type Poison. Print the first and the last Pokemon of this list.
# 4. Print only the name of the best defense Pokemon of type Rock.
# 5. Lookup the markdown cheat sheet and change the last part to
#     1. show the name of the Pokemon in *bold*
#     2. show the Pokemons in an unordered list
#     3. show a horizontal rule in front of the first Pokemon

# %%
# Init the variables for the results
biggestPokemon = pokemon.pokedex[0]
bestAttack = pokemon.pokedex[0]
defenseRock = pokemon.pokedex[0]
firstgeneration = []
poison = []
favorite = None
# Loop over all of the pokemon
for p in pokemon.pokedex:
    # If the current pokemon has more health, than the best before.
    if p.hp > biggestPokemon.hp:
        # The current pokemon is now the biggest (=> most health)
        biggestPokemon = p
    if p.attack > bestAttack.attack:
        bestAttack = p
    if p.defense > defenseRock.defense and p.type=="Rock":
        defenseRock = p
    # Add the current pokemon to the list of the first generation ones.
    # Attention: Using p.generation == 1 doesn't work. In generation only str values are stored.
    if p.generation == '1':
        firstgeneration.append(p)
    if p.type == "Poison":
        posion.append(p)
    # Change p.name to p.name.lower()
    if p.name == 'pikachu':
        favorite = p

# When you prepend your string with f, you can include variables directly inside curly braces.
print (f"{biggestPokemon.name} is the biggest Pokemon with {biggestPokemon.hp} HP.")
print ("{biggestPokemon.name} is the biggest Pokemon with {biggestPokemon.hp} HP.")
print ("Attack Name:" + bestAttack.name + "Attack value:" + str(bestAttack.attack)
print (poison[0], poison[24])
print (defenseRock)



# When you don't want to use the f as above, you can concatenate strings with "+"
print("There are " + str(len(firstgeneration)) + " pokemon of the first generation.")

if (favorite != None):
    print (favorite)
else:
    print ("Sadly your favorite couldn't be found.")
display(Markdown("***"))    
for p in pokemon.pokedex[0:3]:
    display(Markdown(f'Pokemon: **{p.name}** Image ![](https://assets.pokemon.com/assets/cms2/img/pokedex/full/{pokemon.pokedex.index(p)+1:0>3}.png)'))
# Out:
#   File "<ipython-input-29-f048d8ec3ea7>", line 32
#     print(poison[0], poison[24])
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Outlook for next time...
# Next time we will learn about how to extend the possibilities of python with libraries and modules.
#
# Please watch this videos for next time:
#
# | Name | Link |
# |---|---|
# | NumPy | https://www.youtube.com/watch?v=xECXZ3tyONo |
# | Pandas | https://www.youtube.com/watch?v=dcqPhpY7tWk |
# | Webscraping | https://www.youtube.com/watch?v=Mll6emjBFvA |
# | Bokeh | https://www.youtube.com/watch?v=i3-wsgtGhfs |

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, Label, LabelSet, Range1d

output_notebook()

databasis = firstgeneration[0::10]

data = {"x_axis": [p.attack for p in databasis],
       "y_axis":[p.defense for p in databasis],
       "size":[p.hp/2 for p in databasis],
       "name":[p.name for p in databasis],
       "color":[p.color() for p in databasis]}
source = ColumnDataSource(data)
plot = figure(plot_width=400, plot_height=400)
# add a circle renderer with x and y coordinates, size, color, and alpha
plot.circle('x_axis', 'y_axis', size='size', line_color="navy", fill_color='color', fill_alpha=0.5, source=source)
labels = LabelSet(x='x_axis', y='y_axis', text='name', level='glyph', x_offset=3, y_offset=3, source=source,text_font_size='8pt')
plot.add_layout(labels)
show(plot) # show the results
